# %% [markdown]
# <a href="https://colab.research.google.com/github/brainmentorspvtltd/IGDTU_ImageProcessingTF/blob/main/IG_YOLOV8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
import os
HOME = os.getcwd()

# %%
HOME
# Out:
# '/content'

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow
# Out:
# /content/datasets
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 21.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 6.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.5 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=f39a9fe2df36e79d92165e78952abdfd9d71dd771bf5df2f15665683160eecb8
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.0
#     Uninstalling pyparsing-3.1.0:
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="xizrl8SO1HtNPwZyk7if", model_format='yolov8')
project = rf.workspace("team-tcwly").project("hard-hat-sample-41gad")
dataset = project.version(1).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Hard-Hat-Sample-1 in yolov8:: 100%|██████████| 211/211 [00:00<00:00, 2638.35it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode= train model=yolov8s.pt data=/content/datasets/Hard-Hat-Sample-1/data.yaml epochs=5 imgsz=448 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train8
# Out:
# args.yaml					    results.png
# confusion_matrix.png				    train_batch0.jpg
# events.out.tfevents.1688396310.96f3b689ef3f.8539.0  train_batch1.jpg
# F1_curve.png					    train_batch2.jpg
# P_curve.png					    val_batch0_labels.jpg
# PR_curve.png					    val_batch0_pred.jpg
# R_curve.png					    weights
# results.csv

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train8/confusion_matrix.png', width=500)
# Out:
# /content

# %%
Image(filename=f'{HOME}/runs/detect/train8/results.png', width=500)

# %%
Image(filename=f'{HOME}/runs/detect/train8/val_batch0_pred.jpg', width=500)
